# %% [markdown]
# # Exploring eBay Car Sales Data
#
# ## Introduction
#
# In this project, we will clean the data to analyse used car listings. The data sampled from eBay Germany contains 50,000 data points. The original dataset can be found [here](https://www.kaggle.com/orgesleka/used-cars-database/data).
#
# The data dictionary is as follows:
#
# - **dateCrawled:** The date when the ad was first crawled
# - **name:** Name of the car
# - **seller:** Whether the seller is private or a dealer
# - **offerType:** The type of listing
# - **price:** The price advertised price of the car
# - **abtest:** Whether the listing is included in an A/B test
# - **vehicleType:** The type of vehicle
# - **yearOfRegistration:** The year in which the car was first registered
# - **gearbox:** The transmission type
# - **powerPS:** The power of the car in PS
# - **model:** The car model name
# - **kilometer:** How many km's the car has driven
# - **monthOfRegistration:** The month in which the car was first registered
# - **fuelType:** What type of fuel the car uses
# - **brand:** The brand of the car
# - **notRepairedDamage:** If the car has a damage which is not yet repaired
# - **dateCreated:** The date on which the eBay listing was created
# - **nrOfPictures:** The number of pictures in the ad
# - **postalCode:** The postcode for the location of the vehicle
# - **lastSeenOnline:** When the crawler last saw the ad online

# %% [markdown]
# ## Data Load
#
# For this project, we import the pandas and NumPy libraries.

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv",encoding = 'Latin-1')

# %% [markdown]
# ### Column Name Standardisation
#
# We begin by printing an array of the existing column names.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# We then copy this array and will make the following changes to the column names:
#
# - yearOfRegistration will become registration_year
# - monthOfRegistration will become registration_month
# - notRepairedDamage will become unrepaired_damage
# - dateCreated will become ad_created
# - dateCrawled will become date_crawled
#
# We will also convert all remaining column names to lower case.

# %%
'''
Renaming columns
'''

autos.rename(columns={"yearOfRegistration": "registration_year"}, inplace = True)
autos.rename(columns={"monthOfRegistration": "registration_month"}, inplace = True)
autos.rename(columns={"notRepairedDamage": "unrepaired_damage"}, inplace = True)
autos.rename(columns={"dateCreated": "ad_created"}, inplace = True)
autos.rename(columns={"dateCrawled": "date_crawled"}, inplace = True)
autos.rename(columns={"lastSeen": "last_seen"}, inplace = True)

'''
Converting all column headers to lower case
'''
autos.columns = map(str.lower,autos.columns)

autos.columns # Check that this has been completed correctly
# Out:
# Index(['date_crawled', 'name', 'seller', 'offertype', 'price', 'abtest',
#        'vehicletype', 'registration_year', 'gearbox', 'powerps', 'model',
#        'odometer', 'registration_month', 'fueltype', 'brand',
#        'unrepaired_damage', 'ad_created', 'nrofpictures', 'postalcode',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# The column headers needed to be changed for a number of reasons:
#
# - **Simplicity:** Short column names improve readability and make it easier to perform operations in panda.
#
# - **Standardisation:** By converting all column names to lowercase, we don't have to remember where the capital letters are located in the string when working with Pandas

# %% [markdown]
# ## Data Exploration & Observations
#
# As this was successfully loaded and the columns standardised, we will now explore the data.

# %%
print(autos.info()) #This will provide information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# seller                50000 non-null object
# offertype             50000 non-null object
# price                 50000 non-null object
# abtest                50000 non-null object
# vehicletype           44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# powerps               50000 non-null int64
# model                 47242 non-null object
# odometer              50000 non-null object
# registration_month    50000 non-null int64
# fueltype              45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# ad_created            50000 non-null object
# nrofpictures          50000 non-null int64
# postalcode            50000 non-null int64
# last_seen             50000 non-null object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB
# None

# %%
autos.head() #This will provide a sample of the first few rows
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offertype   price   abtest vehicletype  registration_year  \
# 0  privat   Angebot  $5,000  control         bus               2004
# 1  privat   Angebot  $8,500  control   limousine               1997
# 2  privat   Angebot  $8,990     test   limousine               2009
# 3  privat   Angebot  $4,350  control  kleinwagen               2007
# 4  privat   Angebot  $1,350     test       kombi               2003
#
#      gearbox  powerps   model   odometer  registration_month fueltype  \
# 0    manuell      158  andere  150,000km                   3      lpg
# 1  automatik      286     7er  150,000km                   6   benzin
# 2    manuell      102    golf   70,000km                   7   benzin
# 3  automatik       71  fortwo   70,000km                   6   benzin
# 4    manuell        0   focus  150,000km                   7   benzin
#
#         brand unrepaired_damage           ad_created  nrofpictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalcode            last_seen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %%
autos.describe(include="all") # Obtain description statistics
# Out:
#                date_crawled         name  seller offertype  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-03-30 17:37:35  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
# mean                    NaN          NaN     NaN       NaN    NaN    NaN
# std                     NaN          NaN     NaN       NaN    NaN    NaN
# min                     NaN          NaN     NaN       NaN    NaN    NaN
# 25%                     NaN          NaN     NaN       NaN    NaN    NaN
# 50%                     NaN          NaN     NaN       NaN    NaN    NaN
# 75%                     NaN          NaN     NaN       NaN    NaN    NaN
# max                     NaN          NaN     NaN       NaN    NaN    NaN
#
#        vehicletype  registration_year  gearbox       powerps  model  \
# count        44905       50000.000000    47320  50000.000000  47242
# unique           8                NaN        2           NaN    245
# top      limousine                NaN  manuell           NaN   golf
# freq         12859                NaN    36993           NaN   4024
# mean           NaN        2005.073280      NaN    116.355920    NaN
# std            NaN         105.712813      NaN    209.216627    NaN
# min            NaN        1000.000000      NaN      0.000000    NaN
# 25%            NaN        1999.000000      NaN     70.000000    NaN
# 50%            NaN        2003.000000      NaN    105.000000    NaN
# 75%            NaN        2008.000000      NaN    150.000000    NaN
# max            NaN        9999.000000      NaN  17700.000000    NaN
#
#          odometer  registration_month fueltype       brand unrepaired_damage  \
# count       50000        50000.000000    45518       50000             40171
# unique         13                 NaN        7          40                 2
# top     150,000km                 NaN   benzin  volkswagen              nein
# freq        32424                 NaN    30107       10687             35232
# mean          NaN            5.723360      NaN         NaN               NaN
# std           NaN            3.711984      NaN         NaN               NaN
# min           NaN            0.000000      NaN         NaN               NaN
# 25%           NaN            3.000000      NaN         NaN               NaN
# 50%           NaN            6.000000      NaN         NaN               NaN
# 75%           NaN            9.000000      NaN         NaN               NaN
# max           NaN           12.000000      NaN         NaN               NaN
#
#                  ad_created  nrofpictures    postalcode            last_seen
# count                 50000       50000.0  50000.000000                50000
# unique                   76           NaN           NaN                39481
# top     2016-04-03 00:00:00           NaN           NaN  2016-04-07 06:17:27
# freq                   1946           NaN           NaN                    8
# mean                    NaN           0.0  50813.627300                  NaN
# std                     NaN           0.0  25779.747957                  NaN
# min                     NaN           0.0   1067.000000                  NaN
# 25%                     NaN           0.0  30451.000000                  NaN
# 50%                     NaN           0.0  49577.000000                  NaN
# 75%                     NaN           0.0  71540.000000                  NaN
# max                     NaN           0.0  99998.000000                  NaN

# %% [markdown]
# ### Observations
#
# Based on the descriptive statistics above, I've made some obserations:
#
#
# **Columns to change the data type**
#
# - **price**: This needs to be converted into either an integer or a float.
#
# - **odomoter**: This column contains values stored as text, we will need to remove the 'km' after the figure.
#
# **Columns with 'dirty' data**
#
# - **powerps**: The minimum value is 0 and the maximum is 17,700. This seems like an odd range.
#
# - **registration_year**: This has a max of 9999 and a min of 1000 which is far outside a possible range.
#
# - **registration_month**: The minimum value is 0. Does this mean that the car is unregistered?
#
# **Columns to drop**
#
# - **seller**: This column contains 2 values of which 1 is not 'privat'. This column can be dropped.
#
# - **offer_type**: This column contains 2 values of which 1 is not 'Angebot'. This column can be dropped.
#
# - **nrofpictures**: This column is completely empty. This column can be dropped.
#
# - **date_crawled, last_seen, ad_created**: The data in these columns for this project are not required as they don't offer any useful datetime info. We will remove these columns
#
# Let's look at some of these columns in greater detail.

# %%
'''
Registration years
'''

print(autos["registration_year"].value_counts().sort_index(ascending=False).head(10))
print("\n")
print(autos["registration_year"].value_counts().sort_index(ascending=True).head(10))
# Out:
# 9999    4
# 9996    1
# 9000    2
# 8888    1
# 6200    1
# 5911    1
# 5000    4
# 4800    1
# 4500    1
# 4100    1
# Name: registration_year, dtype: int64
#
#
# 1000    1
# 1001    1
# 1111    1
# 1500    1
# 1800    2
# 1910    9
# 1927    1
# 1929    1
# 1931    1
# 1934    2
# Name: registration_year, dtype: int64

# %% [markdown]
# From the above output, we see that a number of registration years are incorrect.  We will need to identify these cars later on.

# %%
'''
Registration month
'''
autos["registration_month"].value_counts().sort_index()
# Out:
# 0     5075
# 1     3282
# 2     3008
# 3     5071
# 4     4102
# 5     4107
# 6     4368
# 7     3949
# 8     3191
# 9     3389
# 10    3651
# 11    3360
# 12    3447
# Name: registration_month, dtype: int64

# %% [markdown]
# From the registration month data, we can see that a number of cars are registered in month 0 which is incorrect. There is a line-ball decision to make, while the month is incorrect, what month the vehicle is registered isn't very important to our analysis. Cars registered in month 0 make up approximately 10% of all listings and the largest group of car registrations. In this instance, we will leave these listings as is.

# %%
'''
Number of pictures
'''

autos["nrofpictures"].value_counts()
# Out:
# 0    50000
# Name: nrofpictures, dtype: int64

# %% [markdown]
# This column will need to be discarded as it won't provide any analytical information.

# %%
'''
Power Values
'''
print(autos["powerps"].value_counts().sort_index(ascending=False).head(10))
print("\n")
print(autos["powerps"].value_counts().sort_index(ascending=True).head(10))
# Out:
# 17700    1
# 16312    1
# 16011    1
# 15016    1
# 15001    1
# 14009    1
# 9011     1
# 8404     1
# 7511     1
# 6512     1
# Name: powerps, dtype: int64
#
#
# 0     5500
# 1        5
# 2        2
# 3        3
# 4        4
# 5       13
# 6        3
# 8        2
# 9        1
# 10       3
# Name: powerps, dtype: int64

# %% [markdown]
# In laymans terms PS is the equivalent of Horsepower. There is quite a large range of power outputs. However we should be concerned with the outliers such as cars with a powerps value of 0 and perhaps those with power outputs greater than say 1100 ps.

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# #### Converting Numeric Values Stored as Text
#
# We need to convert the values in the price and odometer columns into numeric values. To do so we will:
#
# - Remove any non-numeric characters
# - Convert the whole column to a numeric dtype
# - Rename the column so we know what the unit of measurement is

# %%
'''
Converting the price column to numeric value
'''

autos["price"] = autos["price"].str.replace('$','').str.replace(",","")
# remove the $ and , values from each figure

autos["price"] = autos["price"].astype(int)
# convert the whole column to an integer

'''
Converting the odometer column to a numeric value
'''

autos["odometer"] = autos["odometer"].str.replace('kms','').str.replace('km','').str.replace(',','')
# remove either 'kms', 'km' or any comma

autos["odometer"] = autos["odometer"].astype(int)
# convert the whole column to an interger

autos.rename(columns={"odometer": "odometer_km"}, inplace = True)
# rename the odometer column to unclude the UoM.

autos.dtypes
# check that the price and odometer columns now contain integers
# Out:
# date_crawled          object
# name                  object
# seller                object
# offertype             object
# price                  int64
# abtest                object
# vehicletype           object
# registration_year      int64
# gearbox               object
# powerps                int64
# model                 object
# odometer_km            int64
# registration_month     int64
# fueltype              object
# brand                 object
# unrepaired_damage     object
# ad_created            object
# nrofpictures           int64
# postalcode             int64
# last_seen             object
# dtype: object

# %% [markdown]
# We can see from the above that the odometer and price columns now contain numeric values.

# %% [markdown]
# ### Identifying and Eliminating Outliers
#
# As we have converted the odometer and price columns to be integers, we can identify the outliers. We will also identify outliers in the registration column.

# %%
'''
Identify unique values
'''

print(autos["odometer_km"].unique().shape)
print(autos["price"].unique().shape)
print(autos["registration_year"].unique().shape)
print(autos["powerps"].unique().shape)
# Out:
# (13,)
# (2357,)
# (97,)
# (448,)

# %% [markdown]
# We can see that the odometer column contains 13 unique values which suggests that this comes from a pre-defined range.
#
# Price on the other hand has 2,357 unique values so the range of prices is quite wide.
#
# Registration year contains 97 unique values which seem ok on the surface but as we know, there are definitely some questionable items there.
#
# The powerps column contains 436 unique values however as above, there are definitely some questionable items there.

# %%
'''
Series descriptions
'''

print(autos["odometer_km"].describe())
print("\n")
print(autos["price"].describe())
print("\n")
print(autos["registration_year"].describe())
print("\n")
print(autos["powerps"].describe())
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64
#
#
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
#
#
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64
#
#
# count    50000.000000
# mean       116.355920
# std        209.216627
# min          0.000000
# 25%         70.000000
# 50%        105.000000
# 75%        150.000000
# max      17700.000000
# Name: powerps, dtype: float64

# %% [markdown]
# The data descriptions show that the odometer values appear to be quite clean while the price, registration year and powerps values are quite extreme. We will now identify the outliers.

# %% [markdown]
# #### Odometer Outliers

# %%
#Value counts for odometer

autos["odometer_km"].value_counts().sort_index(ascending=False)
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# 5000        967
# Name: odometer_km, dtype: int64

# %% [markdown]
# The odometer values appear fine so we will not be cleaning them. Let's take a look at the price values.

# %% [markdown]
# #### Price Outliers

# %%
#Value counts for price

print(autos["price"].value_counts().sort_index(ascending=False).head(5))
print("\n")
print(autos["price"].value_counts().sort_index(ascending=True).head(5))
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# Name: price, dtype: int64
#
#
# 0    1421
# 1     156
# 2       3
# 3       1
# 5       2
# Name: price, dtype: int64

# %% [markdown]
# From the above, cars with a price of under 100 and cars with a price tag of more than 200,000 are worth exploring further. Lets take a look.

# %%
autos.loc[autos["price"] < 100] # Cars with a price less than $100
# Out:
#               date_crawled                                               name  \
# 25     2016-03-21 21:56:18  Ford_escort_kombi_an_bastler_mit_ghia_ausstattung
# 27     2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
#
# 49496  2016-03-26 13:55:28                                        Bmw_e39_520
# 49504  2016-03-13 19:42:57                                 Meriva_Lpg_1_6_16v
# 49507  2016-03-16 17:38:32                 BMW_528i_E39_Schaltgetriebe_Unfall
# 49525  2016-03-09 17:59:02              Bmw_e36_318_i_Limo_Ringtool_PS_Tuning
# 49528  2016-03-28 19:57:41       BMW_E36__316i_Compact_M_Paket_"Schlachtfest"
# 49538  2016-03-14 10:55:27                 Golf_3_mit_Tuev_.....PREISWERT!!!!
# 49551  2016-03-16 23:40:18        Golf_IV_an_Bastler_zuverkaufen__reserviert_
# 49614  2016-03-09 17:49:39  Verkauf_meine__Audi__A3_.Gegen_tauschen_mit_Di...
# 49728  2016-03-25 16:00:11                     Ford_Focus_1.4_16V_Bastlerauto
# 49739  2016-03-17 15:47:34                          Reparaturfaelligen_twingo
# 49755  2016-04-02 13:46:23                        Mercedes_Benz_w202_unfaller
# 49793  2016-03-05 14:58:49                                  verkaufe_BMW_E_39
# 49843  2016-04-01 08:56:18                                    Mazda_323_F_1.4
# 49845  2016-03-21 00:50:15  Schlachte_VW_Sharan_vr6_Automatik___no_GTI_16V...
# 49880  2016-03-30 08:52:57                                E39_528i_an_Bastler
# 49884  2016-03-11 13:55:30               Audi_a6_2.5l__Schnaeppchen_nur_heute
# 49943  2016-03-16 20:46:08                                         Opel_astra
# 49960  2016-03-25 22:51:55            Ford_KA_zu_verschenken_***Reserviert***
# 49974  2016-03-20 10:52:31  Golf_1_Cabrio_Tuev_Neu_viele_Extras_alles_eing...
# 49984  2016-03-31 22:48:48  Student_sucht_ein__Anfaengerauto___ab_2000_BJ_...
#
#        seller offertype  price   abtest vehicletype  registration_year  \
# 25     privat   Angebot     90  control       kombi               1996
# 27     privat   Angebot      0  control         NaN               2005
# 30     privat   Angebot     80     test  kleinwagen               2002
# 55     privat   Angebot      1     test         NaN               2017
# 64     privat   Angebot     40     test         NaN               2011
# 71     privat   Angebot      0  control         NaN               1990
# 80     privat   Angebot      0  control       coupe               1999
# 87     privat   Angebot      0  control         NaN               2000
# 99     privat   Angebot      0  control      cabrio               2011
# 118    privat   Angebot      0  control         bus               2001
# 146    privat   Angebot      0     test  kleinwagen               1996
# 167    privat   Angebot      0  control         NaN               2011
# 180    privat   Angebot      0     test         NaN               2016
# 226    privat   Angebot      0  control      cabrio               1967
# 234    privat   Angebot      0  control         NaN               2016
# 245    privat   Angebot     50  control  kleinwagen               1997
# 248    privat   Angebot      0     test       kombi               1998
# 259    privat   Angebot      0  control         NaN               2000
# 301    privat   Angebot      0  control         NaN               1990
# 323    privat   Angebot      0  control   limousine               2001
# 327    privat   Angebot      0  control         NaN               2016
# 344    privat   Angebot      1     test         NaN               2000
# 347    privat   Angebot      0     test         suv               1956
# 366    privat   Angebot      0  control         NaN               2000
# 389    privat   Angebot      0  control   limousine               1999
# 418    privat   Angebot      0     test         bus               2003
# 427    privat   Angebot      0     test         bus               2005
# 430    privat   Angebot      0     test         NaN               2007
# 449    privat   Angebot      0     test   limousine               2001
# 487    privat   Angebot      0     test       kombi               1998
# ...       ...       ...    ...      ...         ...                ...
# 49082  privat   Angebot      0     test   limousine               1996
# 49240  privat   Angebot      1     test       kombi               1999
# 49254  privat   Angebot      0     test         NaN               1995
# 49301  privat   Angebot      0     test         NaN               2000
# 49342  privat   Angebot      0     test         NaN               2017
# 49350  privat   Angebot      0  control  kleinwagen               1991
# 49377  privat   Angebot      1  control   limousine               2002
# 49404  privat   Angebot      0  control   limousine               1989
# 49408  privat   Angebot      0  control         NaN               1995
# 49479  privat   Angebot      0  control   limousine               1995
# 49496  privat   Angebot      0  control   limousine               1998
# 49504  privat   Angebot      0  control         bus               2004
# 49507  privat   Angebot      0  control   limousine               1998
# 49525  privat   Angebot      0     test         NaN               2000
# 49528  privat   Angebot      1  control         NaN               2016
# 49538  privat   Angebot      0  control   limousine               1998
# 49551  privat   Angebot      0     test         NaN               2016
# 49614  privat   Angebot      0     test         NaN               2016
# 49728  privat   Angebot      1     test         NaN               2016
# 49739  privat   Angebot      0     test         NaN               2016
# 49755  privat   Angebot      0     test   limousine               1998
# 49793  privat   Angebot      0  control       kombi               2000
# 49843  privat   Angebot     60     test  kleinwagen               1998
# 49845  privat   Angebot      1     test         NaN               2000
# 49880  privat   Angebot      0  control         NaN               2017
# 49884  privat   Angebot      0     test       kombi               1999
# 49943  privat   Angebot      0  control         NaN               2016
# 49960  privat   Angebot      0  control  kleinwagen               1999
# 49974  privat   Angebot      0  control      cabrio               1983
# 49984  privat   Angebot      0     test         NaN               2000
#
#          gearbox  powerps        model  odometer_km  registration_month  \
# 25       manuell      116          NaN       150000                   4
# 27           NaN        0          NaN       150000                   0
# 30       manuell       60      2_reihe       150000                   6
# 55     automatik      224     e_klasse       125000                   7
# 64           NaN        0          5er       150000                   5
# 71       manuell        0          NaN         5000                   0
# 80       manuell       99      primera       150000                   3
# 87           NaN        0          5er       150000                   0
# 99       manuell        0      2_reihe        60000                   7
# 118      manuell      204       sharan       150000                   7
# 146      manuell       75       fiesta        20000                   8
# 167          NaN        0  transporter         5000                   0
# 180      manuell       98      3_reihe       150000                  12
# 226      manuell      160          911         5000                  12
# 234          NaN        0        punto       150000                   0
# 245      manuell       60       twingo        30000                   5
# 248      manuell        0       passat       150000                  10
# 259          NaN        0          NaN         5000                   6
# 301          NaN        0          NaN         5000                   0
# 323    automatik      224     s_klasse       150000                   8
# 327      manuell       90          3er       150000                   2
# 344      manuell      125       andere         5000                   0
# 347          NaN        0       andere       100000                   0
# 366          NaN        0       andere        90000                   0
# 389      manuell       75          NaN       150000                   0
# 418      manuell       80       andere         5000                   5
# 427      manuell      101       vivaro        80000                   8
# 430          NaN        0        focus         5000                   0
# 449      manuell      120         golf       150000                   8
# 487      manuell      136        omega       150000                   8
# ...          ...      ...          ...          ...                 ...
# 49082    manuell       90          NaN       150000                   6
# 49240    manuell        0          NaN       150000                   4
# 49254    manuell        0          NaN       150000                   0
# 49301        NaN        0          NaN       150000                   0
# 49342    manuell       90           80       150000                  10
# 49350    manuell       54         golf       150000                   3
# 49377    manuell      143          3er       150000                   8
# 49404    manuell       90          NaN       150000                   3
# 49408    manuell       60        astra       150000                   0
# 49479    manuell      101           a4       150000                   5
# 49798  2016-03-21 02:00:39                                 Opel_Astra_Caravan
# 49806  2016-03-15 17:56:40                               Mitsubishi__Colt_1_1
# 49815  2016-03-08 10:06:22  SUCHE_TIPPS___Ford_Mustang_Shelby_GT_350_500_K...
# 49817  2016-03-16 17:58:35                                 Mercedes_E240_211k
# 49842  2016-04-02 14:42:45                 Mercedes_Benz_Vito_111_CDI_Kompakt
# 49844  2016-03-26 19:43:51                                Fahrzeug_Ankauf!!!!
# 49849  2016-04-05 11:50:41                  1997_Opel_Vectra_B_1.8_CD_Mit_TÜV
# 49860  2016-04-03 14:49:24                           Tausche_gegen_Opel_Agila
# 49865  2016-03-10 01:37:42  Mercedes_CLK_270_CDI_TÜV_bis_11_2017_klimaauto...
# 49868  2016-03-26 21:50:00                            C_Klasse_200_Kompressor
# 49870  2016-03-08 18:50:51         A2_1.4_16V_S_Line_Leder_interieur_Panorama
# 49871  2016-03-12 19:00:30                       Ford_Fiesta_1_4_TÜV_bis_2018
# 49874  2016-04-02 18:25:23                              Ford_KA_mit_Tuev_2017
# 49876  2016-03-22 17:57:24                             Audi_a5_3.0_tdi_s_line
# 49892  2016-03-14 14:57:03                                         Vw_T_4_Bus
# 49896  2016-03-25 19:51:40                                   Vw_golf_1_cabrio
# 49898  2016-03-31 17:36:41         BMW_318_i.__Wer_in_Tresse_hat_bitte_melden
# 49911  2016-04-02 07:54:30  BMW_X3_Euro4_TÜV_Neu_Klima_Leder_AHK_Panorama_...
# 49926  2016-03-13 00:36:56                                     Vw_golf_cabrio
# 49932  2016-03-14 18:52:18               Mercedes_320_cdi_7_Sitzer_Avantgarde
# 49955  2016-03-30 12:50:18                     Golf_1.9_TDI_DPF_4mot_GT_Sport
# 49982  2016-03-29 18:51:08            Skoda_Fabia_4_Tuerer_Bj:2004__85.000Tkm
# 49984  2016-03-31 22:48:48  Student_sucht_ein__Anfaengerauto___ab_2000_BJ_...
# 49985  2016-04-02 16:38:23                          Verkaufe_meinen_vw_vento!
# 49989  2016-03-11 19:50:37        VW_Polo_zum_Ausschlachten_oder_Wiederaufbau
# 49991  2016-03-06 15:25:19                                         Kleinwagen
# 49993  2016-03-15 18:47:35           Audi_A3__1_8l__Silber;_schoenes_Fahrzeug
#
#        seller offertype   price   abtest vehicletype  registration_year  \
# 4      privat   Angebot    1350     test       kombi               2003
# 8      privat   Angebot     250     test         NaN               2000
# 11     privat   Angebot     350  control         NaN               2000
# 27     privat   Angebot       0  control         NaN               2005
# 32     privat   Angebot     350  control  kleinwagen               1999
# 35     privat   Angebot    1200     test       kombi               1998
# 46     privat   Angebot    9000  control         NaN               2005
# 52     privat   Angebot    3500     test   limousine               1985
# 59     privat   Angebot     700  control         NaN               2016
# 64     privat   Angebot      40     test         NaN               2011
# 71     privat   Angebot       0  control         NaN               1990
# 74     privat   Angebot    1500  control       kombi               2006
# 85     privat   Angebot    5000     test  kleinwagen               2009
# 87     privat   Angebot       0  control         NaN               2000
# 92     privat   Angebot    1900     test         NaN               2000
# 99     privat   Angebot       0  control      cabrio               2011
# 101    privat   Angebot     600  control         NaN               2016
# 102    privat   Angebot     320  control  kleinwagen               2004
# 124    privat   Angebot    3100     test   limousine               2006
# 139    privat   Angebot   11490  control   limousine               2003
# 144    privat   Angebot     150  control   limousine               1995
# 155    privat   Angebot   23900  control         bus               2012
# 164    privat   Angebot    4800  control         NaN               2018
# 167    privat   Angebot       0  control         NaN               2011
# 175    privat   Angebot   13800  control       coupe               1972
# 181    privat   Angebot     700  control  kleinwagen               1999
# 191    privat   Angebot     999     test       kombi               2003
# 192    privat   Angebot   17800  control         bus               2014
# 199    privat   Angebot    1150  control   limousine               1999
# 210    privat   Angebot     890     test         bus               2002
# ...       ...       ...     ...      ...         ...                ...
# 49741  privat   Angebot     400  control  kleinwagen               1998
# 49774  privat   Angebot    2200     test   limousine               2003
# 49777  privat   Angebot    2500  control       kombi               2003
# 49798  privat   Angebot     650     test       kombi               1998
# 49806  privat   Angebot    3000  control  kleinwagen               2007
# 49815  privat   Angebot  130000  control       coupe               1968
# 49817  privat   Angebot    6500  control       kombi               2003
# 49842  privat   Angebot   12500     test         bus               2009
# 49844  privat   Angebot   22222  control         NaN               2005
# 49849  privat   Angebot     650     test   limousine               1997
# 49860  privat   Angebot     800     test      andere               1997
# 49865  privat   Angebot    5200     test       coupe               2004
# 49868  privat   Angebot    4500  control   limousine               2004
# 49870  privat   Angebot    2000     test   limousine               2002
# 49871  privat   Angebot    1800     test   limousine               2003
# 49874  privat   Angebot     100     test  kleinwagen               1999
# 49876  privat   Angebot   14700  control         NaN               2016
# 49892  privat   Angebot    6000  control         bus               2003
# 49896  privat   Angebot     200     test      cabrio               1990
# 49898  privat   Angebot     650  control   limousine               1991
# 49911  privat   Angebot   11500     test         suv               2007
# 49926  privat   Angebot     850  control         NaN               2000
# 49932  privat   Angebot    1400     test       kombi               1999
# 49955  privat   Angebot    3400  control   limousine               2008
# 49982  privat   Angebot    1950  control  kleinwagen               2004
# 49984  privat   Angebot       0     test         NaN               2000
# 49985  privat   Angebot    1000  control         NaN               1995
# 49989  privat   Angebot     150     test  kleinwagen               1997
# 49991  privat   Angebot     500  control         NaN               2016
# 49993  privat   Angebot    1650  control  kleinwagen               1997
#
#          gearbox  powerps        model  odometer_km  registration_month  \
# 4        manuell        0        focus       150000                   7
# 8        manuell        0        arosa       150000                  10
# 11           NaN        0          NaN       150000                   0
# 27           NaN        0          NaN       150000                   0
# 32       manuell        0        corsa       150000                   7
# 35       manuell        0       mondeo       150000                  12
# 46     automatik        0          NaN       150000                   0
# 52           NaN        0       andere         5000                   0
# 59       manuell        0     a_klasse       150000                   0
# 64           NaN        0          5er       150000                   5
# 71       manuell        0          NaN         5000                   0
# 74       manuell        0        astra       150000                   3
# 85       manuell        0        yaris        60000                  12
# 87           NaN        0          5er       150000                   0
# 92           NaN        0          NaN       150000                   0
# 99       manuell        0      2_reihe        60000                   7
# 101          NaN        0      corolla       150000                   0
# 102      manuell        0           ka         5000                   6
# 124          NaN        0       passat       150000                   8
# 139    automatik        0     e_klasse       125000                  10
# 144          NaN        0       andere        90000                   3
# 155    automatik        0       touran        30000                   8
# 164      manuell        0       meriva        80000                   4
# 167          NaN        0  transporter         5000                   0
# 175          NaN        0          NaN        20000                   6
# 181      manuell        0      2_reihe       150000                  10
# 191      manuell        0       mondeo       150000                   3
# 192          NaN        0       vivaro        40000                   0
# 199      manuell        0         clio       150000                   3
# 210    automatik        0     carnival       150000                  11
# ...          ...      ...          ...          ...                 ...
# 49741    manuell        0          NaN        40000                   0
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
# 47948  2016-03-20 17:40:16  Opel_Astra_J_Sports_Tourer_1_4Turbo_60700Km_Na...
# 49085  2016-04-04 08:53:37    Dodge_Unfall_Viper_SRT_10_mit_8.4_Liter__650_PS
# 49263  2016-04-02 15:55:11                             VW_Passat_1.9TDI_Kombi
# 49391  2016-03-18 00:55:16  Lamborghini_Gallardo_LP560_4_E_Gear_"Callisto_...
#
#        seller offertype    price   abtest vehicletype  registration_year  \
# 160    privat   Angebot    50500     test   limousine               2012
# 1699   privat   Angebot     1200     test   limousine               2001
# 2220   privat   Angebot      850  control         NaN               2005
# 2670   privat   Angebot      360  control  kleinwagen               1999
# 2876   privat   Angebot     1990  control      cabrio               1998
# 3753   privat   Angebot     4700  control  kleinwagen               2009
# 4279   privat   Angebot     2850  control   limousine               2005
# 4405   privat   Angebot     2200     test   limousine               1998
# 4464   privat   Angebot     1650  control  kleinwagen               2000
# 4777   privat   Angebot     2200  control       coupe               2000
# 5342   privat   Angebot    23799  control       coupe               2010
# 6923   privat   Angebot        0  control  kleinwagen               1999
# 7556   privat   Angebot      100  control         NaN               1995
# 7798   privat   Angebot    51000  control       coupe               2012
# 8000   privat   Angebot     2599     test         NaN               2016
# 8446   privat   Angebot    79999     test   limousine               2011
# 9335   privat   Angebot    18000     test       coupe               1997
# 9968   privat   Angebot     7200  control  kleinwagen               2010
# 10454  privat   Angebot    50900     test       kombi               2008
# 10556  privat   Angebot      450  control         NaN               1800
# 10659  privat   Angebot      100  control  kleinwagen               1996
# 10668  privat   Angebot    25500  control   limousine               2010
# 10813  privat   Angebot     3950  control  kleinwagen               1972
# 11009  privat   Angebot     2550  control  kleinwagen               2004
# 11311  privat   Angebot     8600  control      andere               2007
# 11433  privat   Angebot   175000     test       coupe               2016
# 11893  privat   Angebot      300     test       coupe               2002
# 11914  privat   Angebot     3200     test         NaN               2017
# 12130  privat   Angebot    18200  control       kombi               2008
# 13573  privat   Angebot      750  control  kleinwagen               1999
# ...       ...       ...      ...      ...         ...                ...
# 34634  privat   Angebot    44900     test       coupe               2012
# 35039  privat   Angebot    11950     test      cabrio               2008
# 36191  privat   Angebot     1499  control   limousine               1998
# 36421  privat   Angebot     6000     test       kombi               2004
# 36973  privat   Angebot     9500     test   limousine               2004
# 37651  privat   Angebot      500  control       kombi               1999
# 39221  privat   Angebot      111     test         NaN               1995
# 40017  privat   Angebot     1500     test       kombi               2003
# 40091  privat   Angebot      600     test       kombi               2000
# 40096  privat   Angebot     3500     test      cabrio               2003
# 40625  privat   Angebot     9900     test         bus               2011
# 40693  privat   Angebot    21400  control       kombi               2008
# 40807  privat   Angebot    74999  control   limousine               2013
# 40975  privat   Angebot    55000  control   limousine               2008
# 41172  privat   Angebot      950     test  kleinwagen               2001
# 41673  privat   Angebot     1900     test  kleinwagen               2001
# 43870  privat   Angebot     5400  control       kombi               2006
# 43987  privat   Angebot    50500  control   limousine               2012
# 44410  privat   Angebot     4300  control         NaN               2016
# 44929  privat   Angebot    19500     test       coupe               1974
# 45465  privat   Angebot     2200  control   limousine               2002
# 45671  privat   Angebot        0     test         NaN               2016
# 46986  privat   Angebot     5000  control         NaN               2018
# 47409  privat   Angebot    36900     test         suv               2011
# 47424  privat   Angebot     1550  control         NaN               2016
# 47634  privat   Angebot  3890000     test       coupe               2006
# 47948  privat   Angebot    11000     test       kombi               2010
# 49085  privat   Angebot    23900  control      cabrio               2008
# 49263  privat   Angebot     1250  control       kombi               2003
# 49391  privat   Angebot   109999     test       coupe               2008
#
#          gearbox  powerps        model  odometer_km  registration_month  \
# 160    automatik      560      m_reihe       100000                   3
# 1699     manuell     6512        corsa       150000                  12
# 2220     manuell     1003           ka         5000                  12
# 2670         NaN     1988        focus       150000                   2
# 2876     manuell      900          NaN       150000                   3
# 3753     manuell     6045         polo       125000                  12
# 4279     manuell      900           c4       100000                   2
# 4405   automatik     1781         golf       150000                  10
# 4464   automatik     1001     a_klasse       150000                   3
# 4777     manuell     1793           tt       150000                   4
# 5342   automatik      612           cl       150000                   2
# 6923   automatik      599       andere       150000                   0
# 7556         NaN      999           a4       150000                   8
# 7798   automatik      551     c_klasse        40000                   7
# 8000     manuell     1779       zafira       150000                   0
# 8446   automatik      610          NaN        60000                   1
# 9335     manuell      640         golf       125000                  10
# 9968     manuell     1016        yaris        30000                   4
# 10454  automatik      850       andere       100000                   6
# 10556        NaN     1800          NaN         5000                   2
# 10659    manuell     3750         polo       125000                   4
# 10668  automatik      555      x_reihe       125000                   7
# 10813    manuell     1300       kaefer       150000                   0
# 11009  automatik     6226       fortwo       125000                   5
# 11311  automatik     3500  transporter       150000                  12
# 11433  automatik      610       andere         5000                   1
# 11893    manuell      551          NaN         5000                   1
# 11914    manuell     1998  transporter       150000                   0
# 12130  automatik      579       andere       150000                   5
# 13573    manuell     1400     a_klasse       150000                   2
# ...          ...      ...          ...          ...                 ...
# 34634  automatik      587       andere        30000                   7
# 35039    manuell    16312           a4        20000                   4
# 36191    manuell     1011          NaN       100000                  12
# 36421  automatik    17700          5er       150000                   7
# 36973  automatik     1771     e_klasse        70000                   9
# 37651    manuell     1001        astra       150000                   7
# 39221        NaN      900       andere         5000                   3
# 40017    manuell     1001        focus       150000                  10
# 40091    manuell     1753        focus       150000                  12
# 40096    manuell      952           ka        70000                   5
# 40625    manuell     1400       touran       150000                   1
# 40693  automatik      740       andere       150000                   6
# 40807  automatik      585     e_klasse       125000                   7
# 40975  automatik      559          NaN        20000                   2
# 41172    manuell     8404       andere       125000                   7
# 41673    manuell     5867        agila        70000                   6
# 43870    manuell     1405       passat       150000                   1
# 43987  automatik      560      m_reihe       100000                   3
# 44410    manuell      696        fabia       150000                   2
# 44929  automatik      600       andere         5000                   7
# 45465  automatik     1704     e_klasse       150000                   1
# 40975             0       68239  2016-03-16 02:44:51
# 41172             0        1594  2016-04-05 13:45:11
# 41673             0       46147  2016-04-06 09:46:07
# 43870             0        3238  2016-03-16 07:45:56
# 43987             0       16225  2016-04-06 02:16:41
# 44410             0        4838  2016-04-06 23:44:26
# 44929             0       38527  2016-03-28 13:15:43
# 45465             0       31812  2016-04-06 09:44:59
# 45671             0       24802  2016-03-20 09:51:49
# 46986             0       12681  2016-03-23 07:41:08
# 47409             0       70190  2016-03-25 19:44:55
# 47424             0       58540  2016-04-02 13:47:09
# 47634             0       60313  2016-04-05 12:07:37
# 47948             0       10315  2016-04-01 02:47:29
# 49085             0       51061  2016-04-06 10:45:58
# 49263             0       33719  2016-04-06 14:46:09
# 49391             0       96052  2016-04-05 21:46:24
#
# [96 rows x 20 columns]

# %% [markdown]
# The majority of cars in this power range have incorrect power levels. We will use this as the upper bounds to remove outliers.

# %% [markdown]
# ### Removing the Outliers from Pricing, PowerPS and Registration Year Data

# %%
'''
Removing the outliers from the pricing data
'''

autos = autos[autos["price"].between(100,350000)]

# %%
autos["price"].describe()
# Out:
# count     48224.000000
# mean       5930.371433
# std        9078.372762
# min         100.000000
# 25%        1250.000000
# 50%        3000.000000
# 75%        7499.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# The values in the price column are now manageable for data analysis.
#
# After that exercise we removed 1,776 rows.

# %%
autos["registration_year"].describe()
# Out:
# count    48224.000000
# mean      2004.730964
# std         87.897388
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The registration year column has a significant range of values ranging from 1000 to 9999. These are certainly some odd values. As the listings end in 2016, any car from 2016 onwards should be removed while any car registered before 1900 should also be removed.

# %%
autos = autos[autos["registration_year"].between(1900,2016)]

# %%
autos["registration_year"].describe()
# Out:
# count    46352.000000
# mean      2002.939787
# std          7.127146
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The registration data looks much better now.

# %%
autos["registration_year"].value_counts(normalize=True).sort_index(ascending=False)
# Out:
# 2016    0.025932
# 2015    0.008198
# 2014    0.014282
# 2013    0.017281
# 2012    0.028219
# 2011    0.034907
# 2010    0.034238
# 2009    0.044874
# 2008    0.047679
# 2007    0.049038
# 2006    0.057560
# 2005    0.062802
# 2004    0.058228
# 2003    0.058099
# 2002    0.053439
# 2001    0.056718
# 2000    0.066966
# 1999    0.062112
# 1998    0.050483
# 1997    0.041530
# 1996    0.029233
# 1995    0.025738
# 1994    0.013505
# 1993    0.009061
# 1992    0.007918
# 1991    0.007292
# 1990    0.007163
# 1989    0.003689
# 1988    0.002869
# 1987    0.001553
#           ...
# 1968    0.000561
# 1967    0.000561
# 1966    0.000475
# 1965    0.000367
# 1964    0.000259
# 1963    0.000173
# 1962    0.000086
# 1961    0.000129
# 1960    0.000475
# 1959    0.000129
# 1958    0.000086
# 1957    0.000043
# 1956    0.000086
# 1955    0.000043
# 1954    0.000043
# 1953    0.000022
# 1952    0.000022
# 1951    0.000043
# 1950    0.000022
# 1948    0.000022
# 1943    0.000022
# 1941    0.000043
# 1939    0.000022
# 1938    0.000022
# 1937    0.000086
# 1934    0.000043
# 1931    0.000022
# 1929    0.000022
# 1927    0.000022
# 1910    0.000043
# Name: registration_year, Length: 78, dtype: float64

# %%
autos = autos[autos["powerps"].between(18,550)] #Removing Outliers from PowerPS

# %%
autos["powerps"].describe()
# Out:
# count    41886.000000
# mean       126.493554
# std         60.990597
# min         18.000000
# 25%         80.000000
# 50%        116.000000
# 75%        150.000000
# max        544.000000
# Name: powerps, dtype: float64

# %% [markdown]
# These figures for Powerps look much better now.

# %% [markdown]
# ### Removing Unnecessary Columns
#
# After removing the outliers, we will now remove unnecessary columns for our analysis.

# %%
autos.info() #To check what columns we currently have.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41886 entries, 0 to 49999
# Data columns (total 20 columns):
# date_crawled          41886 non-null object
# name                  41886 non-null object
# seller                41886 non-null object
# offertype             41886 non-null object
# price                 41886 non-null int64
# abtest                41886 non-null object
# vehicletype           40437 non-null object
# registration_year     41886 non-null int64
# gearbox               41185 non-null object
# powerps               41886 non-null int64
# model                 40321 non-null object
# odometer_km           41886 non-null int64
# registration_month    41886 non-null int64
# fueltype              39769 non-null object
# brand                 41886 non-null object
# unrepaired_damage     35991 non-null object
# ad_created            41886 non-null object
# nrofpictures          41886 non-null int64
# postalcode            41886 non-null int64
# last_seen             41886 non-null object
# dtypes: int64(7), object(13)
# memory usage: 6.7+ MB

# %%
autos.drop(['seller', 'offertype', 'nrofpictures', 'date_crawled', 'last_seen', 'ad_created'], axis='columns', inplace=True)

# %%
autos.info() #See if the redundant columns have now been removed.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41886 entries, 0 to 49999
# Data columns (total 14 columns):
# name                  41886 non-null object
# price                 41886 non-null int64
# abtest                41886 non-null object
# vehicletype           40437 non-null object
# registration_year     41886 non-null int64
# gearbox               41185 non-null object
# powerps               41886 non-null int64
# model                 40321 non-null object
# odometer_km           41886 non-null int64
# registration_month    41886 non-null int64
# fueltype              39769 non-null object
# brand                 41886 non-null object
# unrepaired_damage     35991 non-null object
# postalcode            41886 non-null int64
# dtypes: int64(6), object(8)
# memory usage: 4.8+ MB

# %% [markdown]
# ### Filling in the Blanks
#
# From the last autos.info() run, we can see that there are a few columns with values that are blank. For example, unrepaired_damage has 39,769 values while date_crawled has 41,886.
#
# We can either remove all of these rows with missing values, or we can replace them with "N/A". In my opinion, we're probably better off keeping the rows and using "N/A" to fill the gaps as there is still usable data here.
#
# Of concern the fueltype and unrepaired_damage columns will require filling in.

# %%
#Creating some filters of rows with columns containing blanks to explore the data

bool_series_ft = pd.isnull(autos["fueltype"])
bool_series_unrepaired = pd.isnull(autos["unrepaired_damage"])

# %%
#Viewing rows with blanks in the unrepaired_damage column
autos[bool_series_unrepaired]
# Out:
#                                                     name  price   abtest  \
# 5      Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...   7900     test
# 6      VW_Golf_III_GT_Special_Electronic_Green_Metall...    300     test
# 14     Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...   3999     test
# 18                  Verkaufen_mein_bmw_e36_320_i_touring    300  control
# 20     Audi_A4_Avant_1.9_TDI_*6_Gang*AHK*Klimatronik*...   3500     test
# 34                               Bmw_530d__navi_tuv03/18   2600     test
# 42     Vw_Polo_l.0_/60_PS_Blue_Motion_Technologie_Son...  11900  control
# 56                                          Renault_Clio    650     test
# 67                                      Jeep_Wrangler_YJ   4800     test
# 73                           VW_T3_Doka_1_7D_TÜV_07/2017   2700     test
# 76                            BMW_318i_neustes_Model_0Km  31999  control
# 77                                  Volvo_V40___Tuev_neu   2200     test
# 79                                Seat_Ibiza_1.9_TDI__Fr   6300  control
# 98                     Audi_A4_Cabriolet_2.0_TFSI_S_Line  13500     test
# 107                           zu_verkaufen_Fat_punto_1.9    550     test
# 121                       verkaufe_Ford_focus_1_8_Diesel   1100  control
# 135    Opel_Meriva_B_Panoramadach__Sitz__und_Lenkradh...   8500  control
# 138    Ford_C_Max_Titanium_1_0L._125Ps_Benziner__Magn...  18300     test
# 143    Mercedes_Benz_E_Klasse_W211_320_CDI_Vollaussta...   9655     test
# 147                            VW_Polo_Ersatzteilspender    600  control
# 169    VW_Golf_Variant_1.6_SR__Klima__Schiebedach__AH...   1700  control
# 174                                  Fiat_Punto_sporting    300     test
# 187                               VW_Polo_Kombi_TÜV_2017    900  control
# 190                               An_Bastler_oder_Export    800     test
# 203                                     BMW_316i_Touring    750     test
# 217                                PORSCHE_924S__11/1989   8900  control
# 221                        Opel_Corsa_B_Bastler_Kein_TÜV    150     test
# 222                                    Opel_Astra_Cabrio   1600  control
# 231                      VW_Passat_35i__2.0Liter__115_PS    350  control
# 239                              Mercedes_benz_c_220_cdi   3500  control
# ...                                                  ...    ...      ...
# 49729                         WV_Touran_Highline_2.0_Tdi   3050     test
# 49730                              Volkswagen_Sharan_2.0    999     test
# 49732                      Volkswagen_Golf_Cabriolet_TDI   2800     test
# 49742                                     Renault_Twingo   3490  control
# 49758                             Opel_astra_1_6_eco_tec    600  control
# 49759                       Ford_Focus_2.0_TDCi_Titanium   3600     test
# 49763                        318ti_compact_M_ausstattung   2100  control
# 49771  BMW_120i_150ps_Lederausstattung_Klima_Multi_Le...  11850  control
# 49784            2x_Golf_I_Cabrio_Bel_Air__auch_einzeln_   2800     test
# 49785                                    Bmw_E30_335_m30   6500     test
# 49795  Tausche_7___Sitzer_mit_190_PS___Automatik____>...   3999  control
# 49837                               Ford_Focus_Kombi_1_8   2000  control
# 49839                       Mercedes_Benz_320_Avantgarde   1999     test
# 49852                                   TOP__Golf_3_1.8l   1450  control
# 49862                               opel_astra_F_caravan   1100  control
# 49875               Golf_5_Variant_ab_April_zu_verkaufen   7900  control
# 49879  Tausche_meinen__Daimlerchrysler_Stratus_Cabrio...   2500     test
# 49889             Seat_Ibizia_Stella_1.4__60_PS__Bj.2000   1350  control
# 49890                                      Nissan_Almira    990     test
# 49904  Susuki_Baleno_TÜV_3.2018_Optisch_und_technisch...   1000     test
# 49920                                        Mazda_323_F    700     test
# 49921  Smart_ForTwo_Cabrio_Schwarz_HU+AU_bis_Oktober_...   2350     test
# 49954                                328_Cabrio_Schalter   2490  control
# 49957      Bmw_mit_LPG__super_zustand_2_Jahre_Tuev_klima   2900     test
# 49958                            Golf_3_2.8_vr6_highline   2900     test
# 49961            Golf_2.0_TDI_Sportline_Sonderproduktion   3200  control
# 49964                                 Audi_2_7_TDI_AVANT  12700  control
# 49967                      VW_Passat_2_0_TDI_comfortline   4999     test
# 49980                            Ford_Escort_Turnier_16V    400  control
# 49983                                      Ford_focus_99    600     test
#
#       vehicletype  registration_year    gearbox  powerps        model  \
# 5             bus               2006  automatik      150      voyager
# 6       limousine               1995    manuell       90         golf
# 14     kleinwagen               2007    manuell       75         clio
# 18            bus               1995    manuell      150          3er
# 20          kombi               2003    manuell      131           a4
# 34          kombi               2000  automatik      193          5er
# 42     kleinwagen               2014    manuell       60         polo
# 56     kleinwagen               1997    manuell       58         clio
# 67            suv               1992    manuell      121     wrangler
# 73            bus               1986    manuell       57  transporter
# 76      limousine               2016    manuell      136          3er
# 77          kombi               2001    manuell      108          v40
# 79     kleinwagen               2007    manuell      131        ibiza
# 98         cabrio               2008  automatik      200           a4
# 107    kleinwagen               2001    manuell       85        punto
# 121         kombi               2002    manuell      127        focus
# 135           NaN               2016    manuell       81       meriva
# 138           bus               2015    manuell      125        c_max
# 143     limousine               2006  automatik      224     e_klasse
# 147           NaN               2000    manuell       60         polo
# 169         kombi               2000  automatik      101         golf
# 174    kleinwagen               2000    manuell       80        punto
# 187         kombi               1999    manuell       60         polo
# 190     limousine               2004    manuell      131       mondeo
# 203           NaN               2000    manuell      102          3er
# 217         coupe               1989        NaN      160       andere
# 221    kleinwagen               1995    manuell       45        corsa
# 222        cabrio               1996    manuell       75        astra
# 231         kombi               1994    manuell      115       passat
# 239     limousine               2000    manuell      143     c_klasse
# ...           ...                ...        ...      ...          ...
# 49729       kombi               2005  automatik      140       touran
# 49730       kombi               1998    manuell      116       sharan
# 49732      cabrio               2002    manuell       90         golf
# 49742  kleinwagen               2009    manuell       75       twingo
# 49758   limousine               1997  automatik      101          NaN
# 49759   limousine               2006    manuell      136        focus
# 49763      andere               1997    manuell      140          3er
# 49771   limousine               2004  automatik      150          1er
# 49784      cabrio               1991    manuell       98         golf
# 49785   limousine               1987        NaN      211          3er
# 49795         bus               2001  automatik      190  transporter
# 49837       kombi               2001    manuell      115        focus
# 49839   limousine               1997  automatik      224     e_klasse
# 49852         NaN               2016        NaN       75         golf
# 49862       kombi               1997    manuell       74        astra
# 49875       kombi               2009    manuell       80         golf
# 49879      cabrio               2000    manuell      163       andere
# 49889  kleinwagen               2000    manuell       60        ibiza
# 49890   limousine               2001    manuell       90       almera
# 49904       kombi               2001    manuell       96       andere
# 49920  kleinwagen               2000    manuell       65       andere
# 49921      cabrio               2000  automatik       54       fortwo
# 49954      cabrio               1997    manuell      193          NaN
# 49957       coupe               2000    manuell      150          3er
# 49958   limousine               1994    manuell      174         golf
# 49961   limousine               2007    manuell      140         golf
# 49964       kombi               2010  automatik      192           a4
# 49967       kombi               2006    manuell      140       passat
# 49980       kombi               1995    manuell      105       escort
# 49983  kleinwagen               1999    manuell      101        focus
#
# 231                 NaN       35713
# 239                 NaN       20359
# ...                 ...         ...
# 49729               NaN       22415
# 49730               NaN       96515
# 49732               NaN       76275
# 49742               NaN       47138
# 49758               NaN       20095
# 49759               NaN       91722
# 49763               NaN       35094
# 49771               NaN       32791
# 49784               NaN       51588
# 49785               NaN       25370
# 49795               NaN       66119
# 49837               NaN       26441
# 49839               NaN       68159
# 49852               NaN       67661
# 49862               NaN       61279
# 49875               NaN       16269
# 49879               NaN       41836
# 49889               NaN       50767
# 49890               NaN       96257
# 49904               NaN       33330
# 49920               NaN       36205
# 49921               NaN       55411
# 49954               NaN       45701
# 49957               NaN       41239
# 49958               NaN       24241
# 49961               NaN       65760
# 49964               NaN       54441
# 49967               NaN       70619
# 49980               NaN       56218
# 49983               NaN       52477
#
# [5895 rows x 14 columns]

# %% [markdown]
# From the above, we can see that for the majority of rows missing data in the unrepaired_damage column, the data is still good so we will replace the missing values with 'N/A'.

# %%
autos["unrepaired_damage"].fillna('N/A',inplace=True) #Replace the blank values.

# %%
autos["unrepaired_damage"].value_counts() #Check to see that this is ok now.
# Out:
# nein    32022
# N/A      5895
# ja       3969
# Name: unrepaired_damage, dtype: int64

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41886 entries, 0 to 49999
# Data columns (total 14 columns):
# name                  41886 non-null object
# price                 41886 non-null int64
# abtest                41886 non-null object
# vehicletype           40437 non-null object
# registration_year     41886 non-null int64
# gearbox               41185 non-null object
# powerps               41886 non-null int64
# model                 40321 non-null object
# odometer_km           41886 non-null int64
# registration_month    41886 non-null int64
# fueltype              39769 non-null object
# brand                 41886 non-null object
# unrepaired_damage     41886 non-null object
# postalcode            41886 non-null int64
# dtypes: int64(6), object(8)
# memory usage: 4.8+ MB

# %%
autos["fueltype"].fillna('N/A',inplace=True) #Replace blanks in fueltype column

# %%
autos["fueltype"].value_counts()
# Out:
# benzin     26005
# diesel     13041
# N/A         2117
# lpg          605
# cng           65
# hybrid        37
# elektro        8
# andere         8
# Name: fueltype, dtype: int64

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41886 entries, 0 to 49999
# Data columns (total 14 columns):
# name                  41886 non-null object
# price                 41886 non-null int64
# abtest                41886 non-null object
# vehicletype           40437 non-null object
# registration_year     41886 non-null int64
# gearbox               41185 non-null object
# powerps               41886 non-null int64
# model                 40321 non-null object
# odometer_km           41886 non-null int64
# registration_month    41886 non-null int64
# fueltype              41886 non-null object
# brand                 41886 non-null object
# unrepaired_damage     41886 non-null object
# postalcode            41886 non-null int64
# dtypes: int64(6), object(8)
# memory usage: 4.8+ MB

# %% [markdown]
# ### Removing Remaining Rows with Blanks
#
# Now that the data is relatively clean, for completeness we will now remove all rows that contain blanks.

# %%
cleaned_autos = autos.dropna()

# %%
cleaned_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 49999
# Data columns (total 14 columns):
# name                  38577 non-null object
# price                 38577 non-null int64
# abtest                38577 non-null object
# vehicletype           38577 non-null object
# registration_year     38577 non-null int64
# gearbox               38577 non-null object
# powerps               38577 non-null int64
# model                 38577 non-null object
# odometer_km           38577 non-null int64
# registration_month    38577 non-null int64
# fueltype              38577 non-null object
# brand                 38577 non-null object
# unrepaired_damage     38577 non-null object
# postalcode            38577 non-null int64
# dtypes: int64(6), object(8)
# memory usage: 4.4+ MB

# %% [markdown]
# We now have 38,577 rows remaining that we can use for our analysis.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Brand Analysis by Average Price

# %%
'''
We want to select the top 20 brands by ad-listing numbers
'''

filtered_brands = cleaned_autos["brand"].value_counts().head(20)
print(filtered_brands)
# Out:
# volkswagen       8145
# bmw              4503
# opel             4026
# mercedes_benz    3856
# audi             3571
# ford             2627
# renault          1739
# peugeot          1133
# fiat              939
# seat              728
# skoda             695
# mazda             585
# nissan            584
# citroen           536
# toyota            508
# smart             480
# hyundai           397
# mini              378
# volvo             371
# mitsubishi        315
# Name: brand, dtype: int64

# %%
filtered_brands = filtered_brands.index
print(filtered_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat', 'skoda', 'mazda', 'nissan', 'citroen',
#        'toyota', 'smart', 'hyundai', 'mini', 'volvo', 'mitsubishi'],
#       dtype='object')

# %%
avg_price_by_brand = {}

for brands in filtered_brands:
    selected_rows = cleaned_autos[cleaned_autos["brand"] == brands]
    mean = selected_rows["price"].mean()
    avg_price_by_brand[brands] = mean

# %%
avg_price_by_brand
# Out:
# {'audi': 9958.29095491459,
#  'bmw': 8846.654452587165,
#  'citroen': 4038.001865671642,
#  'fiat': 3057.6900958466454,
#  'ford': 4097.900647125999,
#  'hyundai': 5782.153652392947,
#  'mazda': 4594.270085470085,
#  'mercedes_benz': 9158.69917012448,
#  'mini': 10773.354497354498,
#  'mitsubishi': 3530.146031746032,
#  'nissan': 5209.66095890411,
#  'opel': 3282.6915052160953,
#  'peugeot': 3378.1932921447483,
#  'renault': 2738.608395629672,
#  'seat': 4825.070054945055,
#  'skoda': 6759.576978417266,
#  'smart': 3881.6041666666665,
#  'toyota': 5407.854330708661,
#  'volkswagen': 5950.0902394106815,
#  'volvo': 5326.455525606469}

# %% [markdown]
# Previously we saw that Volkswagen, BMW, Opel, Mercedes Benz and Audi made up the top 5 number of ad-listings by volume.
#
# The average price by brand gives us some insight into the German car market.
#
# French and Italian cars such as Peugeot, Renault, Fiat & Citroen are generally at the more affordable end of the spectrum while German brands tend to be at the higher end of the price range.
#
# Sandwiched in the middle are the Japanese and Korean brands with some of the other minor European brands.

# %%
avg_mileage_by_brand = {}

for brands in filtered_brands:
    selected_rows = cleaned_autos[cleaned_autos["brand"] == brands]
    mean = selected_rows["odometer_km"].mean()
    avg_mileage_by_brand[brands] = mean

# %%
avg_mileage_by_brand
# Out:
# {'audi': 128011.76141136937,
#  'bmw': 132164.11281367976,
#  'citroen': 117957.0895522388,
#  'fiat': 115969.11608093716,
#  'ford': 123587.74267224972,
#  'hyundai': 103438.28715365239,
#  'mazda': 123504.2735042735,
#  'mercedes_benz': 130282.67634854771,
#  'mini': 88095.23809523809,
#  'mitsubishi': 125746.03174603175,
#  'nissan': 116515.4109589041,
#  'opel': 128669.8956780924,
#  'peugeot': 125701.67696381289,
#  'renault': 127032.77745830937,
#  'seat': 120151.0989010989,
#  'skoda': 109510.79136690647,
#  'smart': 97333.33333333333,
#  'toyota': 115187.00787401575,
#  'volkswagen': 127653.7753222836,
#  'volvo': 138450.13477088948}

# %%
bmp_series = pd.Series(avg_price_by_brand)
print(bmp_series)
# Out:
# audi              9958.290955
# bmw               8846.654453
# citroen           4038.001866
# fiat              3057.690096
# ford              4097.900647
# hyundai           5782.153652
# mazda             4594.270085
# mercedes_benz     9158.699170
# mini             10773.354497
# mitsubishi        3530.146032
# nissan            5209.660959
# opel              3282.691505
# peugeot           3378.193292
# renault           2738.608396
# seat              4825.070055
# skoda             6759.576978
# smart             3881.604167
# toyota            5407.854331
# volkswagen        5950.090239
# volvo             5326.455526
# dtype: float64

# %%
df = pd.DataFrame(bmp_series, columns=['mean_price'])
df
# Out:
#                  mean_price
# audi            9958.290955
# bmw             8846.654453
# citroen         4038.001866
# fiat            3057.690096
# ford            4097.900647
# hyundai         5782.153652
# mazda           4594.270085
# mercedes_benz   9158.699170
# mini           10773.354497
# mitsubishi      3530.146032
# nissan          5209.660959
# opel            3282.691505
# peugeot         3378.193292
# renault         2738.608396
# seat            4825.070055
# skoda           6759.576978
# smart           3881.604167
# toyota          5407.854331
# volkswagen      5950.090239
# volvo           5326.455526

# %%
bmm_series = pd.Series(avg_mileage_by_brand)
print(bmm_series)
# Out:
# audi             128011.761411
# bmw              132164.112814
# citroen          117957.089552
# fiat             115969.116081
# ford             123587.742672
# hyundai          103438.287154
# mazda            123504.273504
# mercedes_benz    130282.676349
# mini              88095.238095
# mitsubishi       125746.031746
# nissan           116515.410959
# opel             128669.895678
# peugeot          125701.676964
# renault          127032.777458
# seat             120151.098901
# skoda            109510.791367
# smart             97333.333333
# toyota           115187.007874
# volkswagen       127653.775322
# volvo            138450.134771
# dtype: float64

# %%
df["mean_mileage"] = bmm_series
df
# Out:
#                  mean_price   mean_mileage
# audi            9958.290955  128011.761411
# bmw             8846.654453  132164.112814
# citroen         4038.001866  117957.089552
# fiat            3057.690096  115969.116081
# ford            4097.900647  123587.742672
# hyundai         5782.153652  103438.287154
# mazda           4594.270085  123504.273504
# mercedes_benz   9158.699170  130282.676349
# mini           10773.354497   88095.238095
# mitsubishi      3530.146032  125746.031746
# nissan          5209.660959  116515.410959
# opel            3282.691505  128669.895678
# peugeot         3378.193292  125701.676964
# renault         2738.608396  127032.777458
# seat            4825.070055  120151.098901
# skoda           6759.576978  109510.791367
# smart           3881.604167   97333.333333
# toyota          5407.854331  115187.007874
# volkswagen      5950.090239  127653.775322
# volvo           5326.455526  138450.134771

# %% [markdown]
# Comparing the average price and average mileage, we can see that for cars in a similar group, the higher the average mileage, the lower the average price. Take for example the French car makers Renault, Citroen and Peugeot. These three car makers are competitive in retail price points and car models. In fact, Citroen and Peugeot are basically identical as they share platforms and are the one company. Comparing the average mileage for Citroen and Peugeot, we see that the lower the mileage, the higher the average price.
#
# The same can be said for the big 3 German luxury car makers, BMW, Audi and Mercedes-Benz too as well as grouping the Japanese and Korean brands together. We could make a reasonable assumption that mileage has a negative relationship with price.

# %% [markdown]
# ### Most Popular Models by Brand
#
# To find out which is the most listed model by brand we will use a similar technique to the previous analysis.

# %%
most_listed_model_by_brand = {}

for brands in filtered_brands:
    selected_rows = cleaned_autos["brand"] == brands #for each unique brand
    sorted_rows = cleaned_autos[selected_rows] #use this as a filter
    d_rows = sorted_rows["model"].value_counts() # find the value counts of each model
    most_listed_model_by_brand[brands] = d_rows.index[0] # return the most popular model from the value counts

# %%
most_listed_model_by_brand
# Out:
# {'audi': 'a4',
#  'bmw': '3er',
#  'citroen': 'andere',
#  'fiat': 'punto',
#  'ford': 'focus',
#  'hyundai': 'i_reihe',
#  'mazda': '6_reihe',
#  'mercedes_benz': 'c_klasse',
#  'mini': 'cooper',
#  'mitsubishi': 'colt',
#  'nissan': 'micra',
#  'opel': 'corsa',
#  'peugeot': '2_reihe',
#  'renault': 'twingo',
#  'seat': 'ibiza',
#  'skoda': 'octavia',
#  'smart': 'fortwo',
#  'toyota': 'yaris',
#  'volkswagen': 'golf',
#  'volvo': 'v70'}

# %%
'''
Code for the above loop to return the top value counts for each model by brand.
'''

#b_bool = cleaned_autos["brand"] == "bmw"
#c_bool = cleaned_autos[b_bool]
#d_bool = c_bool["model"].value_counts()
#d_bool
# Out:
# 3er        2363
# 5er        1050
# 1er         490
# x_reihe     277
# 7er         116
# z_reihe     112
# m_reihe      39
# andere       29
# 6er          27
# Name: model, dtype: int64

# %%
pop_model_series = pd.Series(most_listed_model_by_brand)
print(pop_model_series)
# Out:
# audi                   a4
# bmw                   3er
# citroen            andere
# fiat                punto
# ford                focus
# hyundai           i_reihe
# mazda             6_reihe
# mercedes_benz    c_klasse
# mini               cooper
# mitsubishi           colt
# nissan              micra
# opel                corsa
# peugeot           2_reihe
# renault            twingo
# seat                ibiza
# skoda             octavia
# smart              fortwo
# toyota              yaris
# volkswagen           golf
# volvo                 v70
# dtype: object

# %%
df1 = pd.DataFrame(pop_model_series, columns=['top_model'])
df1
# Out:
#               top_model
# audi                 a4
# bmw                 3er
# citroen          andere
# fiat              punto
# ford              focus
# hyundai         i_reihe
# mazda           6_reihe
# mercedes_benz  c_klasse
# mini             cooper
# mitsubishi         colt
# nissan            micra
# opel              corsa
# peugeot         2_reihe
# renault          twingo
# seat              ibiza
# skoda           octavia
# smart            fortwo
# toyota            yaris
# volkswagen         golf
# volvo               v70

# %%
most_listed_model_by_brand_no = {} #Number of listings for the most popular model

for brands in filtered_brands:
    selected_rows = cleaned_autos["brand"] == brands #for each unique brand
    sorted_rows = cleaned_autos[selected_rows] #use this as a filter
    d_rows = sorted_rows["model"].value_counts() # find the value counts of each model
    most_listed_model_by_brand_no[brands] = d_rows[0] # return the number of listings for the most popular model from the value counts

# %%
most_listed_model_by_brand_no
# Out:
# {'audi': 1128,
#  'bmw': 2363,
#  'citroen': 179,
#  'fiat': 331,
#  'ford': 659,
#  'hyundai': 166,
#  'mazda': 144,
#  'mercedes_benz': 1033,
#  'mini': 251,
#  'mitsubishi': 98,
#  'nissan': 194,
#  'opel': 1292,
#  'peugeot': 540,
#  'renault': 470,
#  'seat': 294,
#  'skoda': 286,
#  'smart': 410,
#  'toyota': 113,
#  'volkswagen': 3176,
#  'volvo': 81}

# %%
pop_model_series_no = pd.Series(most_listed_model_by_brand_no)
print(pop_model_series_no)
# Out:
# audi             1128
# bmw              2363
# citroen           179
# fiat              331
# ford              659
# hyundai           166
# mazda             144
# mercedes_benz    1033
# mini              251
# mitsubishi         98
# nissan            194
# opel             1292
# peugeot           540
# renault           470
# seat              294
# skoda             286
# smart             410
# toyota            113
# volkswagen       3176
# volvo              81
# dtype: int64

# %%
df1["no_of_listings"] = pop_model_series_no
df1
# Out:
#               top_model  no_of_listings
# audi                 a4            1128
# bmw                 3er            2363
# citroen          andere             179
# fiat              punto             331
# ford              focus             659
# hyundai         i_reihe             166
# mazda           6_reihe             144
# mercedes_benz  c_klasse            1033
# mini             cooper             251
# mitsubishi         colt              98
# nissan            micra             194
# opel              corsa            1292
# peugeot         2_reihe             540
# renault          twingo             470
# seat              ibiza             294
# skoda           octavia             286
# smart            fortwo             410
# toyota            yaris             113
# volkswagen         golf            3176
# volvo               v70              81

# %% [markdown]
# From the above, the Volkswagen Golf is the most listed model from the sample data. With the exception of the Volvo V70, the most listed cars from each brand are generally small to medium cars.

# %% [markdown]
# ### Price Difference for Damaged Cars

# %%
avg_damaged_by_brand_ja = {}

for brands in filtered_brands:
    selected_rows = cleaned_autos[cleaned_autos["brand"] == brands]
    damage_filter = selected_rows[selected_rows["unrepaired_damage"] == "ja"]
    mean = damage_filter["price"].mean()
    avg_damaged_by_brand_ja[brands] = mean

# %%
avg_damaged_by_brand_ja
# Out:
# {'audi': 3398.9103448275864,
#  'bmw': 3823.460641399417,
#  'citroen': 1887.3035714285713,
#  'fiat': 1259.58,
#  'ford': 1574.2539682539682,
#  'hyundai': 2836.860465116279,
#  'mazda': 1414.0144927536232,
#  'mercedes_benz': 4378.076923076923,
#  'mini': 4749.090909090909,
#  'mitsubishi': 1485.953488372093,
#  'nissan': 2066.9875,
#  'opel': 1535.2227272727273,
#  'peugeot': 1476.8731343283582,
#  'renault': 1261.066037735849,
#  'seat': 1930.7142857142858,
#  'skoda': 3839.5737704918033,
#  'smart': 1558.7692307692307,
#  'toyota': 3721.9333333333334,
#  'volkswagen': 2376.1651234567903,
#  'volvo': 1893.15}

# %%
damaged_cars_series = pd.Series(avg_damaged_by_brand_ja)
print(damaged_cars_series)
# Out:
# audi             3398.910345
# bmw              3823.460641
# citroen          1887.303571
# fiat             1259.580000
# ford             1574.253968
# hyundai          2836.860465
# mazda            1414.014493
# mercedes_benz    4378.076923
# mini             4749.090909
# mitsubishi       1485.953488
# nissan           2066.987500
# opel             1535.222727
# peugeot          1476.873134
# renault          1261.066038
# seat             1930.714286
# skoda            3839.573770
# smart            1558.769231
# toyota           3721.933333
# volkswagen       2376.165123
# volvo            1893.150000
# dtype: float64

# %%
df2 = pd.DataFrame(damaged_cars_series, columns=['damaged_cars'])
df2
# Out:
#                damaged_cars
# audi            3398.910345
# bmw             3823.460641
# citroen         1887.303571
# fiat            1259.580000
# ford            1574.253968
# hyundai         2836.860465
# mazda           1414.014493
# mercedes_benz   4378.076923
# mini            4749.090909
# mitsubishi      1485.953488
# nissan          2066.987500
# opel            1535.222727
# peugeot         1476.873134
# renault         1261.066038
# seat            1930.714286
# skoda           3839.573770
# smart           1558.769231
# toyota          3721.933333
# volkswagen      2376.165123
# volvo           1893.150000

# %%
avg_damaged_by_brand_nein = {}

for brands in filtered_brands:
    selected_rows = cleaned_autos[cleaned_autos["brand"] == brands]
    damage_filter = selected_rows[selected_rows["unrepaired_damage"] == "nein"]
    mean = damage_filter["price"].mean()
    avg_damaged_by_brand_nein[brands] = mean

# %%
avg_damaged_by_brand_nein
# Out:
# {'audi': 11228.818658280923,
#  'bmw': 9695.068355119825,
#  'citroen': 4424.62945368171,
#  'fiat': 3548.212250712251,
#  'ford': 4856.3175572519085,
#  'hyundai': 6297.921875,
#  'mazda': 5394.134831460674,
#  'mercedes_benz': 10008.875866414619,
#  'mini': 11141.760683760684,
#  'mitsubishi': 4197.515021459228,
#  'nissan': 6027.091517857143,
#  'opel': 3787.832114361702,
#  'peugeot': 3847.3859447004606,
#  'renault': 3216.0781860828774,
#  'seat': 5399.3694158075605,
#  'skoda': 7266.2626086956525,
#  'smart': 4068.8693467336684,
#  'toyota': 5628.972911963882,
#  'volkswagen': 6743.192043681747,
#  'volvo': 6020.924092409241}

# %%
undamaged_cars_series = pd.Series(avg_damaged_by_brand_nein)
print(undamaged_cars_series)
# Out:
# audi             11228.818658
# bmw               9695.068355
# citroen           4424.629454
# fiat              3548.212251
# ford              4856.317557
# hyundai           6297.921875
# mazda             5394.134831
# mercedes_benz    10008.875866
# mini             11141.760684
# mitsubishi        4197.515021
# nissan            6027.091518
# opel              3787.832114
# peugeot           3847.385945
# renault           3216.078186
# seat              5399.369416
# skoda             7266.262609
# smart             4068.869347
# toyota            5628.972912
# volkswagen        6743.192044
# volvo             6020.924092
# dtype: float64

# %%
df2["undamaged_cars"] = undamaged_cars_series
df2
# Out:
#                damaged_cars  undamaged_cars
# audi            3398.910345    11228.818658
# bmw             3823.460641     9695.068355
# citroen         1887.303571     4424.629454
# fiat            1259.580000     3548.212251
# ford            1574.253968     4856.317557
# hyundai         2836.860465     6297.921875
# mazda           1414.014493     5394.134831
# mercedes_benz   4378.076923    10008.875866
# mini            4749.090909    11141.760684
# mitsubishi      1485.953488     4197.515021
# nissan          2066.987500     6027.091518
# opel            1535.222727     3787.832114
# peugeot         1476.873134     3847.385945
# renault         1261.066038     3216.078186
# seat            1930.714286     5399.369416
# skoda           3839.573770     7266.262609
# smart           1558.769231     4068.869347
# toyota          3721.933333     5628.972912
# volkswagen      2376.165123     6743.192044
# volvo           1893.150000     6020.924092

# %%
avg_damaged_by_brand_na = {}

for brands in filtered_brands:
    selected_rows = cleaned_autos[cleaned_autos["brand"] == brands]
    damage_filter = selected_rows[selected_rows["unrepaired_damage"] == "N/A"]
    mean = damage_filter["price"].mean()
    avg_damaged_by_brand_na[brands] = mean

# %%
avg_damaged_by_brand_na
# Out:
# {'audi': 5819.7947494033415,
#  'bmw': 5993.334016393443,
#  'citroen': 3320.5254237288136,
#  'fiat': 1856.7007299270074,
#  'ford': 2094.037463976945,
#  'hyundai': 4652.794117647059,
#  'mazda': 2671.7042253521126,
#  'mercedes_benz': 5751.973105134474,
#  'mini': 6833.125,
#  'mitsubishi': 1796.8974358974358,
#  'nissan': 3159.75,
#  'opel': 1984.1159169550174,
#  'peugeot': 2214.206106870229,
#  'renault': 1539.233870967742,
#  'seat': 3093.0,
#  'skoda': 4840.525423728814,
#  'smart': 3629.1428571428573,
#  'toyota': 4054.2,
#  'volkswagen': 3403.743330266789,
#  'volvo': 2716.035714285714}

# %%
unknown_damaged_cars_series = pd.Series(avg_damaged_by_brand_na)
print(unknown_damaged_cars_series)
# Out:
# audi             5819.794749
# bmw              5993.334016
# citroen          3320.525424
# fiat             1856.700730
# ford             2094.037464
# hyundai          4652.794118
# mazda            2671.704225
# mercedes_benz    5751.973105
# mini             6833.125000
# mitsubishi       1796.897436
# nissan           3159.750000
# opel             1984.115917
# peugeot          2214.206107
# renault          1539.233871
# seat             3093.000000
# skoda            4840.525424
# smart            3629.142857
# toyota           4054.200000
# volkswagen       3403.743330
# volvo            2716.035714
# dtype: float64

# %%
df2["unknown_damage"] = unknown_damaged_cars_series
df2
# Out:
#                damaged_cars  undamaged_cars  unknown_damage
# audi            3398.910345    11228.818658     5819.794749
# bmw             3823.460641     9695.068355     5993.334016
# citroen         1887.303571     4424.629454     3320.525424
# fiat            1259.580000     3548.212251     1856.700730
# ford            1574.253968     4856.317557     2094.037464
# hyundai         2836.860465     6297.921875     4652.794118
# mazda           1414.014493     5394.134831     2671.704225
# mercedes_benz   4378.076923    10008.875866     5751.973105
# mini            4749.090909    11141.760684     6833.125000
# mitsubishi      1485.953488     4197.515021     1796.897436
# nissan          2066.987500     6027.091518     3159.750000
# opel            1535.222727     3787.832114     1984.115917
# peugeot         1476.873134     3847.385945     2214.206107
# renault         1261.066038     3216.078186     1539.233871
# seat            1930.714286     5399.369416     3093.000000
# skoda           3839.573770     7266.262609     4840.525424
# smart           1558.769231     4068.869347     3629.142857
# toyota          3721.933333     5628.972912     4054.200000
# volkswagen      2376.165123     6743.192044     3403.743330
# volvo           1893.150000     6020.924092     2716.035714

# %% [markdown]
# We can see from the above that cars which are undamaged command a significant premium over damaged cars. What is interesting is that listings which do not specify if the car is damaged or not have prices that lie in between the two values. That would suggest that if your car is undamaged, you could be losing money by leaving this attribute undefined.
#
# Another interesting observation is the price difference between damaged cars for some manufacturers. Take Audi for example. The price difference between a damaged and undamaged car on average is almost $8,000. Whereas Toyota has the smallest gap between damaged and undamaged cars. This may suggest that Audis are quite expensive to fix or have common major issues with them that are costly to repair. Toyotas on the other hand may be more reliable and could potentially be cheaper to repair.
